# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")
from torsionnet.analysis import load_data_from_pickle
from torsionnet.analysis.analysis import *
from ipywidgets import interact,fixed,IntSlider
import ipywidgets

files = [
    "data/eval/Diff-v2-210414-120522/step_0/ep_0/data.pickle",
    "data/eval/Diff-v2-210414-120522/step_8/ep_1/data.pickle",
]

data = load_data_from_pickle(files)

# %%
bar_plot_episodic("total_rewards", data)
# Out:
# <AxesSubplot:xlabel='run', ylabel='total_rewards'>

# %%
fig, axes = histogram_episodic("reward", data)

# %%
fig, axes = histogram_episodic("energy", data)

# %%
diversity_heatmap(data)
# Out:
# (<Figure size 1440x576 with 4 Axes>,
#  array([<AxesSubplot:xlabel='test0'>, <AxesSubplot:xlabel='test1'>],
#        dtype=object))

# %%
diversity_bar(data)
# Out:
# <AxesSubplot:xlabel='run', ylabel='diversity metric'>

# %%
def conf_viewer(idx):
    mol = data['molecule'][0][idx]
    return MolTo3DView(mol).show()

interact(conf_viewer, idx=ipywidgets.IntSlider(min=0,max=len(data['molecule'][0])-1, step=1))
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=20), Output()), _dom_classes=('widget-interact…
# <function __main__.conf_viewer(idx)>
